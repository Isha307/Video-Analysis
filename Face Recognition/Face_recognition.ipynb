# %%
# !pip install deepface
# Out:
# ...
#      |████████████████████████████████| 61 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 25.7 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for gdown: filename=gdown-4.2.0-py3-none-any.whl size=14273 sha256=e573f576a3d168a356a783b82da07ee2896ee02a1093febddaa7314840caa404
#   Stored in directory: /root/.cache/pip/wheels/8c/17/ff/58721d1fabdb87c21a0529948cf39e2be9af90ddbe4ad65944
# Successfully built gdown
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 3.6.4
#     Uninstalling gdown-3.6.4:
#       Successfully uninstalled gdown-3.6.4
# ...

# %%
from deepface import DeepFace
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('/content/B612_20200301_140643_044.jpg')
plt.imshow(img1)

# %%
img2 = cv2.imread('/content/BeautyPlus_20190807192700703_save.jpg')
plt.imshow(img2)

# %%
img3 = cv2.imread('/content/IMG20190803071755.jpg')
plt.imshow(img3)

# %%
result = DeepFace.verify(img1, img2)
# Out:
# vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /root/.deepface/weights/vgg_face_weights.h5
# 100%|██████████| 580M/580M [00:18<00:00, 31.6MB/s]

# %%
result1 = DeepFace.verify(img1, img3)
result1
# Out:
# {'distance': 0.4154040447796644,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine',
#  'verified': False}

# %%
result2 = DeepFace.verify(img2, img3)
result2
# Out:
# {'distance': 0.45756074493813537,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine',
#  'verified': False}

# %%
result
# Out:
# {'distance': 0.26651830525648024,
#  'max_threshold_to_verify': 0.4,
#  'model': 'VGG-Face',
#  'similarity_metric': 'cosine',
#  'verified': True}
